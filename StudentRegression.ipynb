# %% [markdown]
# <a href="https://colab.research.google.com/github/lipschultzjacob/Student-Regression/blob/main/StudentRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
from sklearn.metrics import mean_absolute_error


import pandas as pd

df = pd.read_csv("student-por.csv", delimiter=';')
df.head()

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

import matplotlib.pyplot as plt

X = df[['traveltime','freetime','G1','G2']]
Y = df['G3']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(X_train, Y_train)

y_pred = model.predict(X_test)

print("R^2 Score:" + str(model.score(X_test, Y_test)))
print("Mean Absolute Error:" + str(mean_absolute_error(Y_test, y_pred)))

plt.scatter(Y_test, y_pred)
plt.xlabel("Actual Grades")
plt.ylabel("Predicted Grades")
plt.title("Actual vs Predicted Grades")
plt.plot([min(Y_test), max(Y_test)], [min(Y_test), max(Y_test)])
# Out:
# R^2 Score:0.8591078776619426
# Mean Absolute Error:0.7314723991907789

# %%
# %pip install ucimlrepo scikit-learn
